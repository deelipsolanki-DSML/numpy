# %% [markdown]
# <img src="https://numpy.org/images/logo.svg"
#      style="width:80px; border-radius:1px; display:block; margin:auto;">
# <h1 style="font-size:40px; text-align:center;">
#     Introduction to Numpy
# </h1>

# %% [markdown]
# <h1 style="font-size:20px; text-align:center;">
#     visit -> <a href="https://numpy.org/">https://numpy.org/</a>
# </h1>

# %% [markdown]
# ## Numpy is a highly optimized library for numerical computation

# %% [markdown]
# <ul>
#   <li><span style="font-size:17px">Easy to use</span></li>
#   <li><span style="font-size:17px">Open Source library</span></li>
#   <li><span style="font-size:17px">Linear Algebra, Statistical Analysis, Random Number generation and more..</span></li>
#   <li><span style="font-size:17px">Faster than regular python code because of C/C++ underlying implementation</span></li>
#
# </ul>

# %% [markdown]
# <br> </br>

# %% [markdown]
# <br> </br>

# %% [markdown]
# <h1 style="font-size:37px; color:darkblue; text-align:left;">
#     Course Content
# </h1>

# %% [markdown]
# <ol style="line-height: 2.5;font-weight:bold;font-size:19px">
#   <li>Creating Numpy arrays, Basic attributes and methods</li>
#   <li>Indexing, Slicing and Basic Arithmatics</li>
#   <li>Element wise array functions and Broadcasting</li>
#   <li>Linear Algebra, Statistics, Random Number Generation with Numpy</li>
#   <li>Application Examples</li>
# </ol>

# %% [markdown]
# <br> </br>

# %% [markdown]
# <br> </br>

# %% [markdown]
# <h1 style="font-size:37px; color:darkblue; text-align:left;">
#     Prerequisites
# </h1>

# %% [markdown]
# <ul>
#   <li><span style="font-size:19px">Basic knowledge of python programming</span></li>
#   <li><span style="font-size:19px">Familiar with some Linear Algebra and basic math</span></li>
#   <li><span style="font-size:19px">Willingness to learn by practicing</span></li>
#   <li><span style="font-size:19px">jupyter and Numpy installed</span></li>
# </ul>

# %% [markdown]
# <br> </br>

# %% [markdown]
# <br> </br>

# %% [markdown]
# <br> </br>

# %% [markdown]
# <br> </br>

# %% [markdown]
# ### Jupyter installation

# %% [markdown]
# <a href="https://jupyter.org/install">https://jupyter.org/install</a>

# %% [markdown]
# ### Numpy installation

# %% [markdown]
# <a href="https://numpy.org/install/">https://numpy.org/install/</a>

# %% [markdown]
# <h1 style="font-size:30px;text-align:center;">
#     END</h1>
